# %%
from i3d_inception import Inception_Inflated3d

# %%
import tensorflow as tf
import keras

from keras.models import Model
from keras import layers
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import Conv3D
from keras.layers import MaxPooling3D
from keras.layers import AveragePooling3D
from keras.layers import Dropout
from keras.layers import Reshape
from keras.layers import Lambda
from keras.layers import GlobalAveragePooling3D

from keras import backend as K

# %%
NUM_FRAMES = 79
FRAME_HEIGHT = 224
FRAME_WIDTH = 224
NUM_RGB_CHANNELS = 3
NUM_FLOW_CHANNELS = 2
NUM_CLASSES = 2

# %% [markdown]
# # Transfer learning

# %%
flow_model = Inception_Inflated3d(
                include_top=False,
                weights='flow_imagenet_and_kinetics',
                input_shape=(None, FRAME_HEIGHT, FRAME_WIDTH, NUM_FLOW_CHANNELS),
                classes=NUM_CLASSES)
# Out:
# E:\GitHub\violence_detection\I3D\i3d_inception.py:101: UserWarning: This model usually expects 1 or 3 input channels. However, it was passed an input_shape with 2 input channels.
#   str(input_shape[-1]) + ' input channels.')

# %%
flow_model.summary()
# Out:
# Model: "i3d_inception"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, None, 224, 2 0
# __________________________________________________________________________________________________
# Conv3d_1a_7x7_conv (Conv3D)     (None, None, 112, 11 43904       input_1[0][0]
# __________________________________________________________________________________________________
# Conv3d_1a_7x7_bn (BatchNormaliz (None, None, 112, 11 192         Conv3d_1a_7x7_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_1a_7x7 (Activation)      (None, None, 112, 11 0           Conv3d_1a_7x7_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_2a_3x3 (MaxPooling3D) (None, None, 56, 56, 0           Conv3d_1a_7x7[0][0]
# __________________________________________________________________________________________________
# Conv3d_2b_1x1_conv (Conv3D)     (None, None, 56, 56, 4096        MaxPool2d_2a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_2b_1x1_bn (BatchNormaliz (None, None, 56, 56, 192         Conv3d_2b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_2b_1x1 (Activation)      (None, None, 56, 56, 0           Conv3d_2b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_2c_3x3_conv (Conv3D)     (None, None, 56, 56, 331776      Conv3d_2b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_2c_3x3_bn (BatchNormaliz (None, None, 56, 56, 576         Conv3d_2c_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_2c_3x3 (Activation)      (None, None, 56, 56, 0           Conv3d_2c_3x3_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_3a_3x3 (MaxPooling3D) (None, None, 28, 28, 0           Conv3d_2c_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1a_1x1_conv (Conv3D)  (None, None, 28, 28, 18432       MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2a_1x1_conv (Conv3D)  (None, None, 28, 28, 3072        MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1a_1x1_bn (BatchNorma (None, None, 28, 28, 288         Conv3d_3b_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2a_1x1_bn (BatchNorma (None, None, 28, 28, 48          Conv3d_3b_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1a_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3b_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2a_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3b_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_3b_3a_3x3 (MaxPooling (None, None, 28, 28, 0           MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_0a_1x1_conv (Conv3D)  (None, None, 28, 28, 12288       MaxPool2d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1b_3x3_conv (Conv3D)  (None, None, 28, 28, 331776      Conv3d_3b_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2b_3x3_conv (Conv3D)  (None, None, 28, 28, 13824       Conv3d_3b_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_3b_1x1_conv (Conv3D)  (None, None, 28, 28, 6144        MaxPool2d_3b_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_0a_1x1_bn (BatchNorma (None, None, 28, 28, 192         Conv3d_3b_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1b_3x3_bn (BatchNorma (None, None, 28, 28, 384         Conv3d_3b_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2b_3x3_bn (BatchNorma (None, None, 28, 28, 96          Conv3d_3b_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_3b_1x1_bn (BatchNorma (None, None, 28, 28, 96          Conv3d_3b_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_0a_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3b_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_1b_3x3 (Activation)   (None, None, 28, 28, 0           Conv3d_3b_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_2b_3x3 (Activation)   (None, None, 28, 28, 0           Conv3d_3b_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3b_3b_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3b_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_3b (Concatenate)          (None, None, 28, 28, 0           Conv3d_3b_0a_1x1[0][0]
#                                                                  Conv3d_3b_1b_3x3[0][0]
#                                                                  Conv3d_3b_2b_3x3[0][0]
#                                                                  Conv3d_3b_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1a_1x1_conv (Conv3D)  (None, None, 28, 28, 32768       Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2a_1x1_conv (Conv3D)  (None, None, 28, 28, 8192        Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1a_1x1_bn (BatchNorma (None, None, 28, 28, 384         Conv3d_3c_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2a_1x1_bn (BatchNorma (None, None, 28, 28, 96          Conv3d_3c_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1a_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3c_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2a_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3c_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_3c_3a_3x3 (MaxPooling (None, None, 28, 28, 0           Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_0a_1x1_conv (Conv3D)  (None, None, 28, 28, 32768       Mixed_3b[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1b_3x3_conv (Conv3D)  (None, None, 28, 28, 663552      Conv3d_3c_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2b_3x3_conv (Conv3D)  (None, None, 28, 28, 82944       Conv3d_3c_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_3b_1x1_conv (Conv3D)  (None, None, 28, 28, 16384       MaxPool2d_3c_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_0a_1x1_bn (BatchNorma (None, None, 28, 28, 384         Conv3d_3c_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1b_3x3_bn (BatchNorma (None, None, 28, 28, 576         Conv3d_3c_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2b_3x3_bn (BatchNorma (None, None, 28, 28, 288         Conv3d_3c_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_3b_1x1_bn (BatchNorma (None, None, 28, 28, 192         Conv3d_3c_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_0a_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3c_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_1b_3x3 (Activation)   (None, None, 28, 28, 0           Conv3d_3c_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_2b_3x3 (Activation)   (None, None, 28, 28, 0           Conv3d_3c_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_3c_3b_1x1 (Activation)   (None, None, 28, 28, 0           Conv3d_3c_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_3c (Concatenate)          (None, None, 28, 28, 0           Conv3d_3c_0a_1x1[0][0]
#                                                                  Conv3d_3c_1b_3x3[0][0]
#                                                                  Conv3d_3c_2b_3x3[0][0]
#                                                                  Conv3d_3c_3b_1x1[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4a_3x3 (MaxPooling3D) (None, None, 14, 14, 0           Mixed_3c[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1a_1x1_conv (Conv3D)  (None, None, 14, 14, 46080       MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2a_1x1_conv (Conv3D)  (None, None, 14, 14, 7680        MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1a_1x1_bn (BatchNorma (None, None, 14, 14, 288         Conv3d_4b_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2a_1x1_bn (BatchNorma (None, None, 14, 14, 48          Conv3d_4b_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4b_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4b_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4b_3a_3x3 (MaxPooling (None, None, 14, 14, 0           MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_0a_1x1_conv (Conv3D)  (None, None, 14, 14, 92160       MaxPool2d_4a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1b_3x3_conv (Conv3D)  (None, None, 14, 14, 539136      Conv3d_4b_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2b_3x3_conv (Conv3D)  (None, None, 14, 14, 20736       Conv3d_4b_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_3b_1x1_conv (Conv3D)  (None, None, 14, 14, 30720       MaxPool2d_4b_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_0a_1x1_bn (BatchNorma (None, None, 14, 14, 576         Conv3d_4b_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1b_3x3_bn (BatchNorma (None, None, 14, 14, 624         Conv3d_4b_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2b_3x3_bn (BatchNorma (None, None, 14, 14, 144         Conv3d_4b_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_3b_1x1_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4b_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_0a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4b_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_1b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4b_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_2b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4b_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4b_3b_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4b_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4b (Concatenate)          (None, None, 14, 14, 0           Conv3d_4b_0a_1x1[0][0]
#                                                                  Conv3d_4b_1b_3x3[0][0]
#                                                                  Conv3d_4b_2b_3x3[0][0]
#                                                                  Conv3d_4b_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1a_1x1_conv (Conv3D)  (None, None, 14, 14, 57344       Mixed_4b[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2a_1x1_conv (Conv3D)  (None, None, 14, 14, 12288       Mixed_4b[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1a_1x1_bn (BatchNorma (None, None, 14, 14, 336         Conv3d_4c_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2a_1x1_bn (BatchNorma (None, None, 14, 14, 72          Conv3d_4c_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4c_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4c_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4c_3a_3x3 (MaxPooling (None, None, 14, 14, 0           Mixed_4b[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_0a_1x1_conv (Conv3D)  (None, None, 14, 14, 81920       Mixed_4b[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1b_3x3_conv (Conv3D)  (None, None, 14, 14, 677376      Conv3d_4c_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2b_3x3_conv (Conv3D)  (None, None, 14, 14, 41472       Conv3d_4c_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_3b_1x1_conv (Conv3D)  (None, None, 14, 14, 32768       MaxPool2d_4c_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_0a_1x1_bn (BatchNorma (None, None, 14, 14, 480         Conv3d_4c_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1b_3x3_bn (BatchNorma (None, None, 14, 14, 672         Conv3d_4c_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2b_3x3_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4c_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_3b_1x1_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4c_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_0a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4c_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_1b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4c_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_2b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4c_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4c_3b_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4c_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4c (Concatenate)          (None, None, 14, 14, 0           Conv3d_4c_0a_1x1[0][0]
#                                                                  Conv3d_4c_1b_3x3[0][0]
#                                                                  Conv3d_4c_2b_3x3[0][0]
#                                                                  Conv3d_4c_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_1a_1x1_conv (Conv3D)  (None, None, 14, 14, 65536       Mixed_4c[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_2a_1x1_conv (Conv3D)  (None, None, 14, 14, 12288       Mixed_4c[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_1a_1x1_bn (BatchNorma (None, None, 14, 14, 384         Conv3d_4d_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_2a_1x1_bn (BatchNorma (None, None, 14, 14, 72          Conv3d_4d_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_1a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4d_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_2a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4d_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4d_3a_3x3 (MaxPooling (None, None, 14, 14, 0           Mixed_4c[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_0a_1x1_conv (Conv3D)  (None, None, 14, 14, 65536       Mixed_4c[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_1b_3x3_conv (Conv3D)  (None, None, 14, 14, 884736      Conv3d_4d_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_2b_3x3_conv (Conv3D)  (None, None, 14, 14, 41472       Conv3d_4d_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_3b_1x1_conv (Conv3D)  (None, None, 14, 14, 32768       MaxPool2d_4d_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_0a_1x1_bn (BatchNorma (None, None, 14, 14, 384         Conv3d_4d_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_1b_3x3_bn (BatchNorma (None, None, 14, 14, 768         Conv3d_4d_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_2b_3x3_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4d_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_3b_1x1_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4d_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_0a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4d_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_1b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4d_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_2b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4d_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4d_3b_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4d_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4d (Concatenate)          (None, None, 14, 14, 0           Conv3d_4d_0a_1x1[0][0]
#                                                                  Conv3d_4d_1b_3x3[0][0]
#                                                                  Conv3d_4d_2b_3x3[0][0]
#                                                                  Conv3d_4d_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_1a_1x1_conv (Conv3D)  (None, None, 14, 14, 73728       Mixed_4d[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_2a_1x1_conv (Conv3D)  (None, None, 14, 14, 16384       Mixed_4d[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_1a_1x1_bn (BatchNorma (None, None, 14, 14, 432         Conv3d_4e_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_2a_1x1_bn (BatchNorma (None, None, 14, 14, 96          Conv3d_4e_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_1a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4e_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_2a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4e_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4e_3a_3x3 (MaxPooling (None, None, 14, 14, 0           Mixed_4d[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_0a_1x1_conv (Conv3D)  (None, None, 14, 14, 57344       Mixed_4d[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_1b_3x3_conv (Conv3D)  (None, None, 14, 14, 1119744     Conv3d_4e_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_2b_3x3_conv (Conv3D)  (None, None, 14, 14, 55296       Conv3d_4e_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_3b_1x1_conv (Conv3D)  (None, None, 14, 14, 32768       MaxPool2d_4e_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_0a_1x1_bn (BatchNorma (None, None, 14, 14, 336         Conv3d_4e_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_1b_3x3_bn (BatchNorma (None, None, 14, 14, 864         Conv3d_4e_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_2b_3x3_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4e_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_3b_1x1_bn (BatchNorma (None, None, 14, 14, 192         Conv3d_4e_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_0a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4e_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_1b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4e_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_2b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4e_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4e_3b_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4e_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4e (Concatenate)          (None, None, 14, 14, 0           Conv3d_4e_0a_1x1[0][0]
#                                                                  Conv3d_4e_1b_3x3[0][0]
#                                                                  Conv3d_4e_2b_3x3[0][0]
#                                                                  Conv3d_4e_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1a_1x1_conv (Conv3D)  (None, None, 14, 14, 84480       Mixed_4e[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2a_1x1_conv (Conv3D)  (None, None, 14, 14, 16896       Mixed_4e[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1a_1x1_bn (BatchNorma (None, None, 14, 14, 480         Conv3d_4f_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2a_1x1_bn (BatchNorma (None, None, 14, 14, 96          Conv3d_4f_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4f_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4f_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_4f_3a_3x3 (MaxPooling (None, None, 14, 14, 0           Mixed_4e[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_0a_1x1_conv (Conv3D)  (None, None, 14, 14, 135168      Mixed_4e[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1b_3x3_conv (Conv3D)  (None, None, 14, 14, 1382400     Conv3d_4f_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2b_3x3_conv (Conv3D)  (None, None, 14, 14, 110592      Conv3d_4f_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_3b_1x1_conv (Conv3D)  (None, None, 14, 14, 67584       MaxPool2d_4f_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_0a_1x1_bn (BatchNorma (None, None, 14, 14, 768         Conv3d_4f_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1b_3x3_bn (BatchNorma (None, None, 14, 14, 960         Conv3d_4f_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2b_3x3_bn (BatchNorma (None, None, 14, 14, 384         Conv3d_4f_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_3b_1x1_bn (BatchNorma (None, None, 14, 14, 384         Conv3d_4f_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_0a_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4f_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_1b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4f_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_2b_3x3 (Activation)   (None, None, 14, 14, 0           Conv3d_4f_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_4f_3b_1x1 (Activation)   (None, None, 14, 14, 0           Conv3d_4f_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_4f (Concatenate)          (None, None, 14, 14, 0           Conv3d_4f_0a_1x1[0][0]
#                                                                  Conv3d_4f_1b_3x3[0][0]
#                                                                  Conv3d_4f_2b_3x3[0][0]
#                                                                  Conv3d_4f_3b_1x1[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_5a_2x2 (MaxPooling3D) (None, None, 7, 7, 8 0           Mixed_4f[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1a_1x1_conv (Conv3D)  (None, None, 7, 7, 1 133120      MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2a_1x1_conv (Conv3D)  (None, None, 7, 7, 3 26624       MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1a_1x1_bn (BatchNorma (None, None, 7, 7, 1 480         Conv3d_5b_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2a_1x1_bn (BatchNorma (None, None, 7, 7, 3 96          Conv3d_5b_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1a_1x1 (Activation)   (None, None, 7, 7, 1 0           Conv3d_5b_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2a_1x1 (Activation)   (None, None, 7, 7, 3 0           Conv3d_5b_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_5b_3a_3x3 (MaxPooling (None, None, 7, 7, 8 0           MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_0a_1x1_conv (Conv3D)  (None, None, 7, 7, 2 212992      MaxPool2d_5a_2x2[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1b_3x3_conv (Conv3D)  (None, None, 7, 7, 3 1382400     Conv3d_5b_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2b_3x3_conv (Conv3D)  (None, None, 7, 7, 1 110592      Conv3d_5b_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_3b_1x1_conv (Conv3D)  (None, None, 7, 7, 1 106496      MaxPool2d_5b_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_0a_1x1_bn (BatchNorma (None, None, 7, 7, 2 768         Conv3d_5b_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1b_3x3_bn (BatchNorma (None, None, 7, 7, 3 960         Conv3d_5b_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2b_3x3_bn (BatchNorma (None, None, 7, 7, 1 384         Conv3d_5b_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_3b_1x1_bn (BatchNorma (None, None, 7, 7, 1 384         Conv3d_5b_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_0a_1x1 (Activation)   (None, None, 7, 7, 2 0           Conv3d_5b_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_1b_3x3 (Activation)   (None, None, 7, 7, 3 0           Conv3d_5b_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_2b_3x3 (Activation)   (None, None, 7, 7, 1 0           Conv3d_5b_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5b_3b_1x1 (Activation)   (None, None, 7, 7, 1 0           Conv3d_5b_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_5b (Concatenate)          (None, None, 7, 7, 8 0           Conv3d_5b_0a_1x1[0][0]
#                                                                  Conv3d_5b_1b_3x3[0][0]
#                                                                  Conv3d_5b_2b_3x3[0][0]
#                                                                  Conv3d_5b_3b_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1a_1x1_conv (Conv3D)  (None, None, 7, 7, 1 159744      Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2a_1x1_conv (Conv3D)  (None, None, 7, 7, 4 39936       Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1a_1x1_bn (BatchNorma (None, None, 7, 7, 1 576         Conv3d_5c_1a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2a_1x1_bn (BatchNorma (None, None, 7, 7, 4 144         Conv3d_5c_2a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1a_1x1 (Activation)   (None, None, 7, 7, 1 0           Conv3d_5c_1a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2a_1x1 (Activation)   (None, None, 7, 7, 4 0           Conv3d_5c_2a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# MaxPool2d_5c_3a_3x3 (MaxPooling (None, None, 7, 7, 8 0           Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_0a_1x1_conv (Conv3D)  (None, None, 7, 7, 3 319488      Mixed_5b[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1b_3x3_conv (Conv3D)  (None, None, 7, 7, 3 1990656     Conv3d_5c_1a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2b_3x3_conv (Conv3D)  (None, None, 7, 7, 1 165888      Conv3d_5c_2a_1x1[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_3b_1x1_conv (Conv3D)  (None, None, 7, 7, 1 106496      MaxPool2d_5c_3a_3x3[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_0a_1x1_bn (BatchNorma (None, None, 7, 7, 3 1152        Conv3d_5c_0a_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1b_3x3_bn (BatchNorma (None, None, 7, 7, 3 1152        Conv3d_5c_1b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2b_3x3_bn (BatchNorma (None, None, 7, 7, 1 384         Conv3d_5c_2b_3x3_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_3b_1x1_bn (BatchNorma (None, None, 7, 7, 1 384         Conv3d_5c_3b_1x1_conv[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_0a_1x1 (Activation)   (None, None, 7, 7, 3 0           Conv3d_5c_0a_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_1b_3x3 (Activation)   (None, None, 7, 7, 3 0           Conv3d_5c_1b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_2b_3x3 (Activation)   (None, None, 7, 7, 1 0           Conv3d_5c_2b_3x3_bn[0][0]
# __________________________________________________________________________________________________
# Conv3d_5c_3b_1x1 (Activation)   (None, None, 7, 7, 1 0           Conv3d_5c_3b_1x1_bn[0][0]
# __________________________________________________________________________________________________
# Mixed_5c (Concatenate)          (None, None, 7, 7, 1 0           Conv3d_5c_0a_1x1[0][0]
#                                                                  Conv3d_5c_1b_3x3[0][0]
#                                                                  Conv3d_5c_2b_3x3[0][0]
#                                                                  Conv3d_5c_3b_1x1[0][0]
# __________________________________________________________________________________________________
# global_avg_pool (AveragePooling (None, None, 1, 1, 1 0           Mixed_5c[0][0]
# ==================================================================================================
# Total params: 12,272,592
# Trainable params: 12,258,032
# Non-trainable params: 14,560
# __________________________________________________________________________________________________

# %% [markdown]
# # Adding classification layer

# %%
from keras import models
from keras import optimizers

# %%
# Creating sequential model
model = models.Sequential()
model.add(flow_model)

# Adding classification layers
dropout_prob = 0.0

model.add(Dropout(dropout_prob))
model.add(Conv3D(NUM_CLASSES, (1, 1, 1), 
                 strides = (1, 1, 1), 
                padding = 'same',
                use_bias = False,
                name = 'Conv3d_6a_1x1'))

#num_frames_remaining = model.layers[-1].output_shape[1]

model.add(Reshape((-1, NUM_CLASSES)))

model.add(Lambda(lambda x: K.mean(x, axis=1, keepdims=False),
                   output_shape=lambda s: (s[0], s[2])))

model.add(Activation('softmax', name = 'prediction'))

# %%
for layer in flow_model.layers[:-21]:
    print(layer.name)
    layer.trainable = False
# Out:
# input_1
# Conv3d_1a_7x7_conv
# Conv3d_1a_7x7_bn
# Conv3d_1a_7x7
# MaxPool2d_2a_3x3
# Conv3d_2b_1x1_conv
# Conv3d_2b_1x1_bn
# Conv3d_2b_1x1
# Conv3d_2c_3x3_conv
# Conv3d_2c_3x3_bn
# Conv3d_2c_3x3
# MaxPool2d_3a_3x3
# Conv3d_3b_1a_1x1_conv
# Conv3d_3b_2a_1x1_conv
# Conv3d_3b_1a_1x1_bn
# Conv3d_3b_2a_1x1_bn
# Conv3d_3b_1a_1x1
# Conv3d_3b_2a_1x1
# MaxPool2d_3b_3a_3x3
# Conv3d_3b_0a_1x1_conv
# Conv3d_3b_1b_3x3_conv
# Conv3d_3b_2b_3x3_conv
# Conv3d_3b_3b_1x1_conv
# Conv3d_3b_0a_1x1_bn
# Conv3d_3b_1b_3x3_bn
# Conv3d_3b_2b_3x3_bn
# Conv3d_3b_3b_1x1_bn
# Conv3d_3b_0a_1x1
# Conv3d_3b_1b_3x3
# Conv3d_3b_2b_3x3
# Conv3d_3b_3b_1x1
# Mixed_3b
# Conv3d_3c_1a_1x1_conv
# Conv3d_3c_2a_1x1_conv
# Conv3d_3c_1a_1x1_bn
# Conv3d_3c_2a_1x1_bn
# Conv3d_3c_1a_1x1
# Conv3d_3c_2a_1x1
# MaxPool2d_3c_3a_3x3
# Conv3d_3c_0a_1x1_conv
# Conv3d_3c_1b_3x3_conv
# Conv3d_3c_2b_3x3_conv
# Conv3d_3c_3b_1x1_conv
# Conv3d_3c_0a_1x1_bn
# Conv3d_3c_1b_3x3_bn
# Conv3d_3c_2b_3x3_bn
# Conv3d_3c_3b_1x1_bn
# Conv3d_3c_0a_1x1
# Conv3d_3c_1b_3x3
# Conv3d_3c_2b_3x3
# Conv3d_3c_3b_1x1
# Mixed_3c
# MaxPool2d_4a_3x3
# Conv3d_4b_1a_1x1_conv
# Conv3d_4b_2a_1x1_conv
# Conv3d_4b_1a_1x1_bn
# Conv3d_4b_2a_1x1_bn
# Conv3d_4b_1a_1x1
# Conv3d_4b_2a_1x1
# MaxPool2d_4b_3a_3x3
# Conv3d_4b_0a_1x1_conv
# Conv3d_4b_1b_3x3_conv
# Conv3d_4b_2b_3x3_conv
# Conv3d_4b_3b_1x1_conv
# Conv3d_4b_0a_1x1_bn
# Conv3d_4b_1b_3x3_bn
# Conv3d_4b_2b_3x3_bn
# Conv3d_4b_3b_1x1_bn
# Conv3d_4b_0a_1x1
# Conv3d_4b_1b_3x3
# Conv3d_4b_2b_3x3
# Conv3d_4b_3b_1x1
# Mixed_4b
# Conv3d_4c_1a_1x1_conv
# Conv3d_4c_2a_1x1_conv
# Conv3d_4c_1a_1x1_bn
# Conv3d_4c_2a_1x1_bn
# Conv3d_4c_1a_1x1
# Conv3d_4c_2a_1x1
# MaxPool2d_4c_3a_3x3
# Conv3d_4c_0a_1x1_conv
# Conv3d_4c_1b_3x3_conv
# Conv3d_4c_2b_3x3_conv
# Conv3d_4c_3b_1x1_conv
# Conv3d_4c_0a_1x1_bn
# Conv3d_4c_1b_3x3_bn
# Conv3d_4c_2b_3x3_bn
# Conv3d_4c_3b_1x1_bn
# Conv3d_4c_0a_1x1
# Conv3d_4c_1b_3x3
# Conv3d_4c_2b_3x3
# Conv3d_4c_3b_1x1
# Mixed_4c
# Conv3d_4d_1a_1x1_conv
# Conv3d_4d_2a_1x1_conv
# Conv3d_4d_1a_1x1_bn
# Conv3d_4d_2a_1x1_bn
# Conv3d_4d_1a_1x1
# Conv3d_4d_2a_1x1
# MaxPool2d_4d_3a_3x3
# Conv3d_4d_0a_1x1_conv
# Conv3d_4d_1b_3x3_conv
# Conv3d_4d_2b_3x3_conv
# Conv3d_4d_3b_1x1_conv
# Conv3d_4d_0a_1x1_bn
# Conv3d_4d_1b_3x3_bn
# Conv3d_4d_2b_3x3_bn
# Conv3d_4d_3b_1x1_bn
# Conv3d_4d_0a_1x1
# Conv3d_4d_1b_3x3
# Conv3d_4d_2b_3x3
# Conv3d_4d_3b_1x1
# Mixed_4d
# Conv3d_4e_1a_1x1_conv
# Conv3d_4e_2a_1x1_conv
# Conv3d_4e_1a_1x1_bn
# Conv3d_4e_2a_1x1_bn
# Conv3d_4e_1a_1x1
# Conv3d_4e_2a_1x1
# MaxPool2d_4e_3a_3x3
# Conv3d_4e_0a_1x1_conv
# Conv3d_4e_1b_3x3_conv
# Conv3d_4e_2b_3x3_conv
# Conv3d_4e_3b_1x1_conv
# Conv3d_4e_0a_1x1_bn
# Conv3d_4e_1b_3x3_bn
# Conv3d_4e_2b_3x3_bn
# Conv3d_4e_3b_1x1_bn
# Conv3d_4e_0a_1x1
# Conv3d_4e_1b_3x3
# Conv3d_4e_2b_3x3
# Conv3d_4e_3b_1x1
# Mixed_4e
# Conv3d_4f_1a_1x1_conv
# Conv3d_4f_2a_1x1_conv
# Conv3d_4f_1a_1x1_bn
# Conv3d_4f_2a_1x1_bn
# Conv3d_4f_1a_1x1
# Conv3d_4f_2a_1x1
# MaxPool2d_4f_3a_3x3
# Conv3d_4f_0a_1x1_conv
# Conv3d_4f_1b_3x3_conv
# Conv3d_4f_2b_3x3_conv
# Conv3d_4f_3b_1x1_conv
# Conv3d_4f_0a_1x1_bn
# Conv3d_4f_1b_3x3_bn
# Conv3d_4f_2b_3x3_bn
# Conv3d_4f_3b_1x1_bn
# Conv3d_4f_0a_1x1
# Conv3d_4f_1b_3x3
# Conv3d_4f_2b_3x3
# Conv3d_4f_3b_1x1
# Mixed_4f
# MaxPool2d_5a_2x2
# Conv3d_5b_1a_1x1_conv
# Conv3d_5b_2a_1x1_conv
# Conv3d_5b_1a_1x1_bn
# Conv3d_5b_2a_1x1_bn
# Conv3d_5b_1a_1x1
# Conv3d_5b_2a_1x1
# MaxPool2d_5b_3a_3x3
# Conv3d_5b_0a_1x1_conv
# Conv3d_5b_1b_3x3_conv
# Conv3d_5b_2b_3x3_conv
# Conv3d_5b_3b_1x1_conv
# Conv3d_5b_0a_1x1_bn
# Conv3d_5b_1b_3x3_bn
# Conv3d_5b_2b_3x3_bn
# Conv3d_5b_3b_1x1_bn
# Conv3d_5b_0a_1x1
# Conv3d_5b_1b_3x3
# Conv3d_5b_2b_3x3
# Conv3d_5b_3b_1x1
# Mixed_5b

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# i3d_inception (Functional)   (None, None, 1, 1, 1024)  12272592
# _________________________________________________________________
# dropout (Dropout)            (None, None, 1, 1, 1024)  0
# _________________________________________________________________
# Conv3d_6a_1x1 (Conv3D)       (None, None, 1, 1, 2)     2048
# _________________________________________________________________
# reshape (Reshape)            (None, None, 2)           0
# _________________________________________________________________
# lambda (Lambda)              (None, 2)                 0
# _________________________________________________________________
# prediction (Activation)      (None, 2)                 0
# =================================================================
# Total params: 12,274,640
# Trainable params: 2,785,520
# Non-trainable params: 9,489,120
# _________________________________________________________________

# %% [markdown]
# # Data generators

# %%
import numpy as np
from keras.utils import Sequence
from keras.utils import np_utils
import os
import random
import math

# %%
class DataGenerator(Sequence):
    """Data Generator inherited from keras.utils.Sequence
    Args: 
        directory: the path of data set, and each sub-folder will be assigned to one class
        batch_size: the number of data points in each batch
        shuffle: whether to shuffle the data per epoch
    Note:
        If you want to load file with other data format, please fix the method of "load_data" as you want
    """
    def __init__(self, directory, batch_size=1, shuffle=True, data_augmentation=True, 
                 target_frames = 79, crop_dim = (224, 224), seed = None, flip = True):
        # Initialize the params
        self.batch_size = batch_size
        self.directory = directory
        self.shuffle = shuffle
        self.data_aug = data_augmentation
        self.target_frames = target_frames
        self.seed = seed
        self.crop_dim = crop_dim
        self.flip = True
        # Load all the save_path of files, and create a dictionary that save the pair of "data:label"
        self.X_path, self.Y_dict = self.search_data() 
        # Print basic statistics information
        self.print_stats()
        return None
    
    def search_data(self):
        X_path = []
        Y_dict = {}
        # list all kinds of sub-folders
        self.dirs = sorted(os.listdir(self.directory))
        one_hots = np_utils.to_categorical(range(len(self.dirs)))
        for i,folder in enumerate(self.dirs):
            folder_path = os.path.join(self.directory,folder)
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path,file)
                # append the each file path, and keep its label  
                X_path.append(file_path)
                Y_dict[file_path] = one_hots[i]
        return X_path, Y_dict
    
    def print_stats(self):
        # calculate basic information
        self.n_files = len(self.X_path)
        self.n_classes = len(self.dirs)
        self.indexes = np.arange(len(self.X_path))
        np.random.shuffle(self.indexes)
        # Output states
        print("Found {} files belonging to {} classes.".format(self.n_files,self.n_classes))
        for i,label in enumerate(self.dirs):
            print('%10s : '%(label),i)
        return None
    
    def __len__(self):
        # calculate the iterations of each epoch
        steps_per_epoch = np.ceil(len(self.X_path) / float(self.batch_size))
        return int(steps_per_epoch)
    
    def __getitem__(self, index):
        """Get the data of each batch
        """
        # get the indexs of each batch
        batch_indexs = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # using batch_indexs to get path of current batch
        batch_path = [self.X_path[k] for k in batch_indexs]
        # get batch data
        batch_x, batch_y = self.data_generation(batch_path)
        return batch_x, batch_y
    
    def on_epoch_end(self):
        # shuffle the data at each end of epoch
        if self.shuffle == True:
            np.random.shuffle(self.indexes)
            
    def data_generation(self, batch_path):
        # load data into memory, you can change the np.load to any method you want        
        batch_x = [self.load_data(x) for x in batch_path]
        batch_y = [self.Y_dict[x] for x in batch_path]
        # transfer the data format and take one-hot coding for labels
        batch_x = np.array(batch_x)
        batch_y = np.array(batch_y)
        return batch_x, batch_y
    
    def dynamic_crop(self, video):
        video_dim = video.shape
        video_width = video_dim[2]
        video_height = video_dim[3]
        
        if self.data_aug:
            x_max = video_width - self.crop_dim[0]
            y_max = video_height - self.crop_dim[1]

            x = random.randint(0, x_max)
            y = random.randint(0, y_max)
            
        else:
            x_center = math.ceil(video_width/2)
            y_center = math.ceil(video_height/2)
            
            x = x_center - math.ceil(self.crop_dim[0]/2)
            y = y_center - math.ceil(self.crop_dim[1]/2)
                        
        return video[:,:,x:x+self.crop_dim[0],y:y+self.crop_dim[1],:]
        
    
    def frame_sampling(self, video):
        # get total frames of input video
        len_frames = video.shape[1]
        
        # If the video is shorter than needed
        if len_frames < self.target_frames:
            # Times the video need to be looped to get 64 frames
            times = self.target_frames//len_frames
            remainder = self.target_frames%len_frames
            # Creating new array to store cat video
            new_video = video
            
            # Repeat the video as many times as needed
            for n in range(1,times):
                new_video = np.concatenate((new_video, video), axis = 1)
            # Add part of the video if needed
            if remainder > 0:
                new_video = np.concatenate((new_video, video[:,:remainder,:,:]), axis = 1)
            
            return new_video
               
        # If the video is longer than needed
        elif len_frames > self.target_frames:
            # Set random start
            start_frame = random.randint(0,len_frames - self.target_frames)
            end_frame = start_frame + self.target_frames
            
            new_video = video[:,start_frame:end_frame,:,:]
            
            return new_video
        
        # If the video is fine
        elif len_frames == self.target_frames:
            return video
    
    def random_flip(self, video): 
        # Flip on width (left-rigth)
        if random.randint(0,1) == 1:
            video = np.flip(video, axis = 3)
                
        return video
    
    def load_data(self, path):
        data = np.load(path)['arr_0']
    
        # Sampling frames
        if self.target_frames is not None:
            data = self.frame_sampling(video = data)
        
        # Center if data_aug is false and random if data_aug is true
        data = self.dynamic_crop(data)
        
        # If it needs flip
        if self.flip:
            data = self.random_flip(data)

        return data[0]

# %%
batch_size = 8
path_train = '../datai3d/flow/train/'
path_val = '../datai3d/flow/validation/'

# %%
train_generator = DataGenerator(directory=path_train, 
                                batch_size=batch_size, 
                                data_augmentation=True)

validation_generator = DataGenerator(directory=path_val, 
                                batch_size=batch_size, 
                                data_augmentation=False,
                                     target_frames = None,
                                flip = False)
# Out:
# Found 1207 files belonging to 2 classes.
#      Fight :  0
#   NonFight :  1
# Found 393 files belonging to 2 classes.
#      Fight :  0
#   NonFight :  1

# %%
x, y = validation_generator.__getitem__(1)

# %%
x.shape
# Out:
# (8, 124, 224, 224, 2)

# %% [markdown]
# # Training

# %%
# Parameters
epochs = 100
steps_per_epoch = train_generator.n_files//batch_size
validation_steps = validation_generator.n_files//batch_size

# %%
# Callbacks
filepath = 'checkpoints/weights_i3dflow.hdf5'

reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', 
                                                 factor=0.1,
                                                 patience=5, 
                                                 min_lr=0.0001,
                                                verbose = 1)

checkpoint = tf.keras.callbacks.ModelCheckpoint(filepath, 
                                                monitor='val_loss', 
                                                verbose=1, 
                                                save_best_only=True, 
                                                save_weights_only=False, 
                                                mode='auto', 
                                                save_freq='epoch')

earlystop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss', 
                                             restore_best_weights = True, 
                                             patience = 10, 
                                             min_delta = 0.01,
                                            verbose = 1)

callbacks = [reduce_lr, checkpoint, earlystop]

# %%
optimizer = keras.optimizers.SGD(learning_rate = 0.01, momentum = 0.9)

model.compile(optimizer=optimizer, loss='CategoricalCrossentropy', metrics=['accuracy'])

# %%
history = model.fit(
      train_generator,
      steps_per_epoch=steps_per_epoch,
      epochs=epochs,
      validation_data=validation_generator,
      validation_steps=validation_steps,
      callbacks = callbacks,
      verbose=1)
# Out:
# Epoch 1/100
# 150/150 [==============================] - 1251s 8s/step - loss: 0.6255 - accuracy: 0.6717 - val_loss: 0.5947 - val_accuracy: 0.6964
#
# Epoch 00001: val_loss improved from inf to 0.59468, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 2/100
# 150/150 [==============================] - 1258s 8s/step - loss: 0.5258 - accuracy: 0.7540 - val_loss: 0.5573 - val_accuracy: 0.7423
#
# Epoch 00002: val_loss improved from 0.59468 to 0.55733, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 3/100
# 150/150 [==============================] - 1273s 8s/step - loss: 0.5225 - accuracy: 0.7352 - val_loss: 0.5675 - val_accuracy: 0.6913
#
# Epoch 00003: val_loss did not improve from 0.55733
# Epoch 4/100
# 150/150 [==============================] - 1226s 8s/step - loss: 0.4659 - accuracy: 0.7867 - val_loss: 0.6052 - val_accuracy: 0.7041
#
# Epoch 00004: val_loss did not improve from 0.55733
# Epoch 5/100
# 150/150 [==============================] - 1236s 8s/step - loss: 0.4928 - accuracy: 0.7795 - val_loss: 0.5272 - val_accuracy: 0.7551
#
# Epoch 00005: val_loss improved from 0.55733 to 0.52715, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 6/100
# 150/150 [==============================] - 1257s 8s/step - loss: 0.4726 - accuracy: 0.7636 - val_loss: 0.5313 - val_accuracy: 0.7602
#
# Epoch 00006: val_loss did not improve from 0.52715
# Epoch 7/100
# 150/150 [==============================] - 1234s 8s/step - loss: 0.4820 - accuracy: 0.7674 - val_loss: 0.5227 - val_accuracy: 0.7398
#
# Epoch 00007: val_loss improved from 0.52715 to 0.52265, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 8/100
# 150/150 [==============================] - 1236s 8s/step - loss: 0.3997 - accuracy: 0.8157 - val_loss: 0.5177 - val_accuracy: 0.7551
#
# Epoch 00008: val_loss improved from 0.52265 to 0.51766, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 9/100
# 150/150 [==============================] - 1256s 8s/step - loss: 0.3973 - accuracy: 0.8140 - val_loss: 0.5603 - val_accuracy: 0.7219
#
# Epoch 00009: val_loss did not improve from 0.51766
# Epoch 10/100
# 150/150 [==============================] - 1252s 8s/step - loss: 0.4389 - accuracy: 0.7980 - val_loss: 0.5160 - val_accuracy: 0.7526
#
# Epoch 00010: val_loss improved from 0.51766 to 0.51597, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 11/100
# 150/150 [==============================] - 1230s 8s/step - loss: 0.4099 - accuracy: 0.8040 - val_loss: 0.5582 - val_accuracy: 0.7168
#
# Epoch 00011: val_loss did not improve from 0.51597
# Epoch 12/100
# 150/150 [==============================] - 1244s 8s/step - loss: 0.4340 - accuracy: 0.8099 - val_loss: 0.5093 - val_accuracy: 0.7806
#
# Epoch 00012: val_loss improved from 0.51597 to 0.50932, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 13/100
# 150/150 [==============================] - 1251s 8s/step - loss: 0.4015 - accuracy: 0.7917 - val_loss: 0.5056 - val_accuracy: 0.7551
#
# Epoch 00013: val_loss improved from 0.50932 to 0.50560, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 14/100
# 150/150 [==============================] - 1237s 8s/step - loss: 0.4018 - accuracy: 0.8100 - val_loss: 0.5249 - val_accuracy: 0.7398
#
# Epoch 00014: val_loss did not improve from 0.50560
# Epoch 15/100
# 150/150 [==============================] - 1242s 8s/step - loss: 0.4291 - accuracy: 0.8238 - val_loss: 0.5543 - val_accuracy: 0.7551
#
# Epoch 00015: val_loss did not improve from 0.50560
# Epoch 16/100
# 150/150 [==============================] - 1291s 9s/step - loss: 0.3993 - accuracy: 0.8167 - val_loss: 0.5067 - val_accuracy: 0.7449
#
# Epoch 00016: val_loss did not improve from 0.50560
# Epoch 17/100
# 150/150 [==============================] - 1301s 9s/step - loss: 0.3891 - accuracy: 0.8362 - val_loss: 0.5317 - val_accuracy: 0.7577
#
# Epoch 00017: val_loss did not improve from 0.50560
# Epoch 18/100
# 150/150 [==============================] - 1240s 8s/step - loss: 0.3849 - accuracy: 0.8245 - val_loss: 0.5452 - val_accuracy: 0.7296
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0009999999776482583.
#
# Epoch 00018: val_loss did not improve from 0.50560
# Epoch 19/100
# 150/150 [==============================] - 1249s 8s/step - loss: 0.4179 - accuracy: 0.8141 - val_loss: 0.5200 - val_accuracy: 0.7551
#
# Epoch 00019: val_loss did not improve from 0.50560
# Epoch 20/100
# 150/150 [==============================] - 1243s 8s/step - loss: 0.3463 - accuracy: 0.8434 - val_loss: 0.5095 - val_accuracy: 0.7372
#
# Epoch 00020: val_loss did not improve from 0.50560
# Epoch 21/100
# 150/150 [==============================] - 1242s 8s/step - loss: 0.3424 - accuracy: 0.8252 - val_loss: 0.5242 - val_accuracy: 0.7551
#
# Epoch 00021: val_loss did not improve from 0.50560
# Epoch 22/100
# 150/150 [==============================] - 1246s 8s/step - loss: 0.3366 - accuracy: 0.8333 - val_loss: 0.5025 - val_accuracy: 0.7474
#
# Epoch 00022: val_loss improved from 0.50560 to 0.50247, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 23/100
# 150/150 [==============================] - 1270s 8s/step - loss: 0.3410 - accuracy: 0.8506 - val_loss: 0.4909 - val_accuracy: 0.7704
#
# Epoch 00023: val_loss improved from 0.50247 to 0.49090, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 24/100
# 150/150 [==============================] - 1249s 8s/step - loss: 0.3481 - accuracy: 0.8297 - val_loss: 0.4853 - val_accuracy: 0.7628
#
# Epoch 00024: val_loss improved from 0.49090 to 0.48533, saving model to checkpoints\weights_i3drgb.hdf5
# Epoch 25/100
# 150/150 [==============================] - 1241s 8s/step - loss: 0.3313 - accuracy: 0.8556 - val_loss: 0.5167 - val_accuracy: 0.7347
#
# Epoch 00025: val_loss did not improve from 0.48533
# Epoch 26/100
# 150/150 [==============================] - 1244s 8s/step - loss: 0.3524 - accuracy: 0.8557 - val_loss: 0.4947 - val_accuracy: 0.7602
#
# Epoch 00026: val_loss did not improve from 0.48533
# Epoch 27/100
# 150/150 [==============================] - 1243s 8s/step - loss: 0.3347 - accuracy: 0.8525 - val_loss: 0.5051 - val_accuracy: 0.7628
#
# Epoch 00027: val_loss did not improve from 0.48533
# Epoch 28/100
# 150/150 [==============================] - 1241s 8s/step - loss: 0.3304 - accuracy: 0.8533 - val_loss: 0.5080 - val_accuracy: 0.7500
#
# Epoch 00028: val_loss did not improve from 0.48533
# Epoch 29/100
# 150/150 [==============================] - 1241s 8s/step - loss: 0.3155 - accuracy: 0.8691 - val_loss: 0.4951 - val_accuracy: 0.7526
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00029: val_loss did not improve from 0.48533
# Epoch 30/100
# 150/150 [==============================] - 1243s 8s/step - loss: 0.3209 - accuracy: 0.8691 - val_loss: 0.5212 - val_accuracy: 0.7500
#
# Epoch 00030: val_loss did not improve from 0.48533
# Epoch 31/100
# 150/150 [==============================] - 1243s 8s/step - loss: 0.3269 - accuracy: 0.8471 - val_loss: 0.5010 - val_accuracy: 0.7500
#
# Epoch 00031: val_loss did not improve from 0.48533
# Epoch 32/100
# 150/150 [==============================] - 1241s 8s/step - loss: 0.3015 - accuracy: 0.8769 - val_loss: 0.5061 - val_accuracy: 0.7526
#
# Epoch 00032: val_loss did not improve from 0.48533
# Epoch 33/100
# 150/150 [==============================] - 1244s 8s/step - loss: 0.3044 - accuracy: 0.8719 - val_loss: 0.5132 - val_accuracy: 0.7577
#
# Epoch 00033: val_loss did not improve from 0.48533
# Restoring model weights from the end of the best epoch.
# Epoch 00033: early stopping

# %%
import pickle
with open('history_i3dflow', 'wb') as file_pi:
    pickle.dump(history.history, file_pi)

# %% [markdown]
# # Test

# %%
path_test = '../datai3d/flow/test/'

# %%
test_generator = DataGenerator(directory=path_test,
                               shuffle = False,
                                batch_size=batch_size, 
                                data_augmentation=False,
                                     target_frames = None,
                                flip = False)
# Out:
# Found 400 files belonging to 2 classes.
#      Fight :  0
#   NonFight :  1

# %%
model.evaluate(test_generator, 
               steps = test_generator.n_files//batch_size, 
               return_dict =  True)
# Out:
# 50/50 [==============================] - 346s 7s/step - loss: 0.4474 - accuracy: 0.7775
# {'loss': 0.4473906457424164, 'accuracy': 0.7774999737739563}
