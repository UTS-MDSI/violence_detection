# %% [markdown]
# # Important:
# - uncommment pip install keras and tensorflow in library for colab
# - uncomment the parts below with multiple GPU if we are using multiple GPU

# %% [markdown]
# # Libraries

# %%
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn

# %%
#!pip uninstall keras 
# !pip install keras==2.2.4
# Out:
# Collecting keras==2.2.4
#   Downloading https://files.pythonhosted.org/packages/5e/10/aa32dad071ce52b5502266b5c659451cfd6ffcbf14e6c8c4f16c0ff5aaab/Keras-2.2.4-py2.py3-none-any.whl (312kB)
#      |████████████████████████████████| 317kB 6.9MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (2.10.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.1.2)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.15.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras==2.2.4) (1.4.1)
# Collecting keras-applications>=1.0.6
#   Downloading https://files.pythonhosted.org/packages/71/e3/19762fdfc62877ae9102edf6342d71b28fbfd9dea3d2f96a882ce099b03f/Keras_Applications-1.0.8-py3-none-any.whl (50kB)
#      |████████████████████████████████| 51kB 6.7MB/s
# Installing collected packages: keras-applications, keras
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# Successfully installed keras-2.2.4 keras-applications-1.0.8

# %%
#!pip uninstall tensorflow 
# !pip install tensorflow==1.14
# Out:
# Collecting tensorflow==1.14
#   Downloading https://files.pythonhosted.org/packages/f4/28/96efba1a516cdacc2e2d6d081f699c001d414cc8ca3250e6d59ae657eb2b/tensorflow-1.14.0-cp37-cp37m-manylinux1_x86_64.whl (109.3MB)
#      |████████████████████████████████| 109.3MB 61kB/s
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.8.1)
# Collecting tensorflow-estimator<1.15.0rc0,>=1.14.0rc0
#   Downloading https://files.pythonhosted.org/packages/3c/d5/21860a5b11caf0678fbc8319341b0ae21a07156911132e0e71bffed0510d/tensorflow_estimator-1.14.0-py2.py3-none-any.whl (488kB)
#      |████████████████████████████████| 491kB 46.9MB/s
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.2)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (3.12.4)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.36.2)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.12.1)
# Collecting tensorboard<1.15.0,>=1.14.0
#   Downloading https://files.pythonhosted.org/packages/91/2d/2ed263449a078cd9c8a9ba50ebd50123adf1f8cfbea1492f9084169b89d9/tensorboard-1.14.0-py3-none-any.whl (3.1MB)
#      |████████████████████████████████| 3.2MB 48.8MB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.15.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.32.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.1.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.2.0)
# Requirement already satisfied: numpy<2.0,>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (1.19.5)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.12.0)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.14) (0.3.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.14) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.6.1->tensorflow==1.14) (56.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.3.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (1.0.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.10.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<1.15.0,>=1.14.0->tensorflow==1.14) (3.4.1)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed tensorboard-1.14.0 tensorflow-1.14.0 tensorflow-estimator-1.14.0

# %%
import numpy as np
import os
from time import time
import cv2

from keras.utils import Sequence
from keras.utils import np_utils


from keras.models import Sequential, Input, Model
from keras.layers import Dense, Flatten, Conv3D, MaxPooling3D, Dropout, BatchNormalization, Activation, LeakyReLU, Add, Multiply
from keras.regularizers import l2
from keras.layers.core import Lambda


import keras.backend as K
from keras.callbacks import LearningRateScheduler

#from keras.utils import multi_gpu_model  
from keras.optimizers import Adam, SGD

import tensorflow as tf

# import tensorflow as tf
# from tensorflow import keras
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense
# from tensorflow.keras.layers import Dropout
# Out:
# Using TensorFlow backend.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# # Data generator: download and data augmentation

# %%
from keras.utils import Sequence
from keras.utils import np_utils

class DataGenerator(Sequence):
    """Data Generator inherited from keras.utils.Sequence
    Args: 
        directory: the path of data set, and each sub-folder will be assigned to one class
        batch_size: the number of data points in each batch
        shuffle: whether to shuffle the data per epoch
    Note:
        If you want to load file with other data format, please fix the method of "load_data" as you want
    """
    def __init__(self, directory, batch_size=1, shuffle=True, data_augmentation=True):
        # Initialize the params
        self.batch_size = batch_size
        self.directory = directory
        self.shuffle = shuffle
        self.data_aug = data_augmentation
        # Load all the save_path of files, and create a dictionary that save the pair of "data:label"
        self.X_path, self.Y_dict = self.search_data() 
        # Print basic statistics information
        self.print_stats()
        return None
        
    def search_data(self):
        X_path = []
        Y_dict = {}
        # list all kinds of sub-folders
        self.dirs = sorted(os.listdir(self.directory))
        one_hots = np_utils.to_categorical(range(len(self.dirs)))
        for i,folder in enumerate(self.dirs):
            folder_path = os.path.join(self.directory,folder)
            for file in os.listdir(folder_path):
                file_path = os.path.join(folder_path,file)
                # append the each file path, and keep its label  
                X_path.append(file_path)
                Y_dict[file_path] = one_hots[i]
        return X_path, Y_dict
    
    def print_stats(self):
        # calculate basic information
        self.n_files = len(self.X_path)
        self.n_classes = len(self.dirs)
        self.indexes = np.arange(len(self.X_path))
        np.random.shuffle(self.indexes)
        # Output states
        print("Found {} files belonging to {} classes.".format(self.n_files,self.n_classes))
        for i,label in enumerate(self.dirs):
            print('%10s : '%(label),i)
        return None
    
    def __len__(self):
        # calculate the iterations of each epoch
        steps_per_epoch = np.ceil(len(self.X_path) / float(self.batch_size))
        return int(steps_per_epoch)

    def __getitem__(self, index):
        """Get the data of each batch
        """
        # get the indexs of each batch
        batch_indexs = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        # using batch_indexs to get path of current batch
        batch_path = [self.X_path[k] for k in batch_indexs]
        # get batch data
        batch_x, batch_y = self.data_generation(batch_path)
        return batch_x, batch_y

    def on_epoch_end(self):
        # shuffle the data at each end of epoch
        if self.shuffle == True:
            np.random.shuffle(self.indexes)

    def data_generation(self, batch_path):
        # load data into memory, you can change the np.load to any method you want
        batch_x = [self.load_data(x) for x in batch_path]
        batch_y = [self.Y_dict[x] for x in batch_path]
        # transfer the data format and take one-hot coding for labels
        batch_x = np.array(batch_x)
        batch_y = np.array(batch_y)
        return batch_x, batch_y
      
    def normalize(self, data):
        mean = np.mean(data)
        std = np.std(data)
        return (data-mean) / std
    
    def random_flip(self, video, prob):
        s = np.random.rand()
        if s < prob:
            video = np.flip(m=video, axis=2)
        return video    
    
    def uniform_sampling(self, video, target_frames=64):
        # get total frames of input video and calculate sampling interval 
        len_frames = int(len(video))
        interval = int(np.ceil(len_frames/target_frames))
        # init empty list for sampled video and 
        sampled_video = []
        for i in range(0,len_frames,interval):
            sampled_video.append(video[i])     
        # calculate numer of padded frames and fix it 
        num_pad = target_frames - len(sampled_video)
        padding = []
        if num_pad>0:
            for i in range(-num_pad,0):
                try: 
                    padding.append(video[i])
                except:
                    padding.append(video[0])
            sampled_video += padding     
        # get sampled video
        return np.array(sampled_video, dtype=np.float32)
    
    def random_clip(self, video, target_frames=64):
        start_point = np.random.randint(len(video)-target_frames)
        return video[start_point:start_point+target_frames]
    
    def dynamic_crop(self, video):
        # extract layer of optical flow from video
        opt_flows = video[...,3]
        # sum of optical flow magnitude of individual frame
        magnitude = np.sum(opt_flows, axis=0)
        # filter slight noise by threshold 
        thresh = np.mean(magnitude)
        magnitude[magnitude<thresh] = 0
        # calculate center of gravity of magnitude map and adding 0.001 to avoid empty value
        x_pdf = np.sum(magnitude, axis=1) + 0.001
        y_pdf = np.sum(magnitude, axis=0) + 0.001
        # normalize PDF of x and y so that the sum of probs = 1
        x_pdf /= np.sum(x_pdf)
        y_pdf /= np.sum(y_pdf)
        # randomly choose some candidates for x and y 
        x_points = np.random.choice(a=np.arange(224), size=10, replace=True, p=x_pdf)
        y_points = np.random.choice(a=np.arange(224), size=10, replace=True, p=y_pdf)
        # get the mean of x and y coordinates for better robustness
        x = int(np.mean(x_points))
        y = int(np.mean(y_points))
        # avoid to beyond boundaries of array
        x = max(56,min(x,167))
        y = max(56,min(y,167))
        # get cropped video 
        return video[:,x-56:x+56,y-56:y+56,:]  
    
    def color_jitter(self,video):
        # range of s-component: 0-1
        # range of v component: 0-255
        s_jitter = np.random.uniform(-0.2,0.2)
        v_jitter = np.random.uniform(-30,30)
        for i in range(len(video)):
            hsv = cv2.cvtColor(video[i], cv2.COLOR_RGB2HSV)
            s = hsv[...,1] + s_jitter
            v = hsv[...,2] + v_jitter
            s[s<0] = 0
            s[s>1] = 1
            v[v<0] = 0
            v[v>255] = 255
            hsv[...,1] = s
            hsv[...,2] = v
            video[i] = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
        return video
        
    def load_data(self, path):
        # load the processed .npy files which have 5 channels (1-3 for RGB, 4-5 for optical flows)
        data = np.load(path, mmap_mode='r')
        data = np.float32(data)
        # sampling 64 frames uniformly from the entire video
        data = self.uniform_sampling(video=data, target_frames=64)
        # whether to utilize the data augmentation
        if  self.data_aug:
            data[...,:3] = self.color_jitter(data[...,:3])
            data = self.random_flip(data, prob=0.5)
        # normalize rgb images and optical flows, respectively
        data[...,:3] = self.normalize(data[...,:3])
        data[...,3:] = self.normalize(data[...,3:])
        return data

# %% [markdown]
# # Build the model

# %%
# extract the rgb images (the same as RGB model are in space 3 (greyscale))
def get_rgb(input_x):
    rgb = input_x[...,:3]
    return rgb

# extract the optical flows (they are 2d vectors, the final 2)
def get_opt(input_x):
    opt= input_x[...,3:5]
    return opt

# %%
inputs = Input(shape=(64,224,224,5))

#Wraps arbitrary expressions as a Layer object.
rgb = Lambda(get_rgb,output_shape=None)(inputs)
opt = Lambda(get_opt,output_shape=None)(inputs)

##################################################### RGB channel
rgb = Conv3D(
    16, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = Conv3D(
    16, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = MaxPooling3D(pool_size=(1,2,2))(rgb)

rgb = Conv3D(
    16, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = Conv3D(
    16, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = MaxPooling3D(pool_size=(1,2,2))(rgb)

rgb = Conv3D(
    32, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = Conv3D(
    32, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = MaxPooling3D(pool_size=(1,2,2))(rgb)

rgb = Conv3D(
    32, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = Conv3D(
    32, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(rgb)
rgb = MaxPooling3D(pool_size=(1,2,2))(rgb)

##################################################### Optical Flow channel
opt = Conv3D(
    16, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(opt)
opt = Conv3D(
    16, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(opt)
opt = MaxPooling3D(pool_size=(1,2,2))(opt)

opt = Conv3D(
    16, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(opt)
opt = Conv3D(
    16, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(opt)
opt = MaxPooling3D(pool_size=(1,2,2))(opt)

opt = Conv3D(
    32, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(opt)
opt = Conv3D(
    32, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(opt)
opt = MaxPooling3D(pool_size=(1,2,2))(opt)

opt = Conv3D(
    32, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='sigmoid', padding='same')(opt)
opt = Conv3D(
    32, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='sigmoid', padding='same')(opt)
opt = MaxPooling3D(pool_size=(1,2,2))(opt)


##################################################### Fusion and Pooling
x = Multiply()([rgb,opt])
x = MaxPooling3D(pool_size=(8,1,1))(x)

##################################################### Merging Block
x = Conv3D(
    64, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Conv3D(
    64, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = MaxPooling3D(pool_size=(2,2,2))(x)

x = Conv3D(
    64, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Conv3D(
    64, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = MaxPooling3D(pool_size=(2,2,2))(x)

x = Conv3D(
    128, kernel_size=(1,3,3), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = Conv3D(
    128, kernel_size=(3,1,1), strides=(1,1,1), kernel_initializer='he_normal', activation='relu', padding='same')(x)
x = MaxPooling3D(pool_size=(2,3,3))(x)

##################################################### FC Layers
x = Flatten()(x)
x = Dense(128,activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(32, activation='relu')(x)

# Build the model
pred = Dense(2, activation='softmax')(x)
model = Model(inputs=inputs, outputs=pred)
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:74: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:517: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4185: The name tf.truncated_normal is deprecated. Please use tf.random.truncated_normal instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:4138: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:133: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 64, 224, 224, 0
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 64, 224, 224, 0           input_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 64, 224, 224, 0           input_1[0][0]
# __________________________________________________________________________________________________
# conv3d_1 (Conv3D)               (None, 64, 224, 224, 448         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv3d_9 (Conv3D)               (None, 64, 224, 224, 304         lambda_2[0][0]
# __________________________________________________________________________________________________
# conv3d_2 (Conv3D)               (None, 64, 224, 224, 784         conv3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_10 (Conv3D)              (None, 64, 224, 224, 784         conv3d_9[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_1 (MaxPooling3D)  (None, 64, 112, 112, 0           conv3d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_5 (MaxPooling3D)  (None, 64, 112, 112, 0           conv3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_3 (Conv3D)               (None, 64, 112, 112, 2320        max_pooling3d_1[0][0]
# __________________________________________________________________________________________________
# conv3d_11 (Conv3D)              (None, 64, 112, 112, 2320        max_pooling3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_4 (Conv3D)               (None, 64, 112, 112, 784         conv3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_12 (Conv3D)              (None, 64, 112, 112, 784         conv3d_11[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_2 (MaxPooling3D)  (None, 64, 56, 56, 1 0           conv3d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_6 (MaxPooling3D)  (None, 64, 56, 56, 1 0           conv3d_12[0][0]
# __________________________________________________________________________________________________
# conv3d_5 (Conv3D)               (None, 64, 56, 56, 3 4640        max_pooling3d_2[0][0]
# __________________________________________________________________________________________________
# conv3d_13 (Conv3D)              (None, 64, 56, 56, 3 4640        max_pooling3d_6[0][0]
# __________________________________________________________________________________________________
# conv3d_6 (Conv3D)               (None, 64, 56, 56, 3 3104        conv3d_5[0][0]
# __________________________________________________________________________________________________
# conv3d_14 (Conv3D)              (None, 64, 56, 56, 3 3104        conv3d_13[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_3 (MaxPooling3D)  (None, 64, 28, 28, 3 0           conv3d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_7 (MaxPooling3D)  (None, 64, 28, 28, 3 0           conv3d_14[0][0]
# __________________________________________________________________________________________________
# conv3d_7 (Conv3D)               (None, 64, 28, 28, 3 9248        max_pooling3d_3[0][0]
# __________________________________________________________________________________________________
# conv3d_15 (Conv3D)              (None, 64, 28, 28, 3 9248        max_pooling3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_8 (Conv3D)               (None, 64, 28, 28, 3 3104        conv3d_7[0][0]
# __________________________________________________________________________________________________
# conv3d_16 (Conv3D)              (None, 64, 28, 28, 3 3104        conv3d_15[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_4 (MaxPooling3D)  (None, 64, 14, 14, 3 0           conv3d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_8 (MaxPooling3D)  (None, 64, 14, 14, 3 0           conv3d_16[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 64, 14, 14, 3 0           max_pooling3d_4[0][0]
#                                                                  max_pooling3d_8[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_9 (MaxPooling3D)  (None, 8, 14, 14, 32 0           multiply_1[0][0]
# __________________________________________________________________________________________________
# conv3d_17 (Conv3D)              (None, 8, 14, 14, 64 18496       max_pooling3d_9[0][0]
# __________________________________________________________________________________________________
# conv3d_18 (Conv3D)              (None, 8, 14, 14, 64 12352       conv3d_17[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_10 (MaxPooling3D) (None, 4, 7, 7, 64)  0           conv3d_18[0][0]
# __________________________________________________________________________________________________
# conv3d_19 (Conv3D)              (None, 4, 7, 7, 64)  36928       max_pooling3d_10[0][0]
# __________________________________________________________________________________________________
# conv3d_20 (Conv3D)              (None, 4, 7, 7, 64)  12352       conv3d_19[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_11 (MaxPooling3D) (None, 2, 3, 3, 64)  0           conv3d_20[0][0]
# __________________________________________________________________________________________________
# conv3d_21 (Conv3D)              (None, 2, 3, 3, 128) 73856       max_pooling3d_11[0][0]
# __________________________________________________________________________________________________
# conv3d_22 (Conv3D)              (None, 2, 3, 3, 128) 49280       conv3d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling3d_12 (MaxPooling3D) (None, 1, 1, 1, 128) 0           conv3d_22[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 128)          0           max_pooling3d_12[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       flatten_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 128)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 32)           4128        dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 2)            66          dense_2[0][0]
# ==================================================================================================
# Total params: 272,690
# Trainable params: 272,690
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks

# %%
def scheduler(epoch):
    # Every 10 epochs, the learning rate is reduced to 1/10 of the original
    if epoch % 10 == 0 and epoch != 0:
        lr = K.get_value(model.optimizer.lr)
        K.set_value(model.optimizer.lr, lr * 0.5)
    return K.get_value(model.optimizer.lr)

reduce_lr = LearningRateScheduler(scheduler)

#with multiple gpu
# def scheduler(epoch):
#     if epoch % 10 == 0 and epoch != 0:
#         lr = K.get_value(parallel_model.optimizer.lr)
#         K.set_value(parallel_model.optimizer.lr, lr * 0.7)
#     return K.get_value(parallel_model.optimizer.lr)

# reduce_lr = LearningRateScheduler(scheduler)

# %% [markdown]
# ## Save the model

# %%
from keras.callbacks import ModelCheckpoint, CSVLogger
import keras

class MyCbk(keras.callbacks.Callback):

    def __init__(self, model):
         self.model_to_save = model

    def on_epoch_end(self, epoch, logs=None):
        self.model_to_save.save('Logs/model_at_epoch_%d.h5' % (epoch+1))

check_point = MyCbk(model)


# filename = 'Logs/ours_log.csv'
# csv_logger = CSVLogger(filename, separator=',', append=True)

# %%
callbacks_list = [check_point, reduce_lr]

# %% [markdown]
# Set the GPUs and make it parallel (NOT for COLAB)

# %%
#strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"], 
#                                         cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

#otra forma
#parallel_model = tf.distribute.MirroredStrategy(devices=["/gpu:0", "/gpu:1"], 
# cross_device_ops=tf.distribute.HierarchicalCopyAllReduce())

# %%
# #only with cuda
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"

# parallel_model = multi_gpu_model(model, gpus=2)

#with multiple GPU
# os.environ["CUDA_VISIBLE_DEVICES"] = "0,1,2,3"

# from keras.utils import multi_gpu_model   
# parallel_model = multi_gpu_model(model, gpus=4)

# %%
#know the devices
# from tensorflow.python.client import device_lib

# print(device_lib.list_local_devices())

# %% [markdown]
# ## Model compilling

# %%
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])

#with multiple GPU
# sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
# parallel_model.compile(optimizer=sgd, loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
#set parameters
num_epochs  = 4
num_workers = 16
batch_size  = 4

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from google.colab import auth
auth.authenticate_user()
project_id = 'apt-terrain-310201'
# !gcloud config set project {project_id}
# !gsutil ls
# Out:
# Updated property [core/project].
# gs://violence/

# %%
bucket_name = 'violence'
# !gsutil -m cp -r /content/gdrive/MyDrive/42028/Dataset_Split/new/ gs://{bucket_name}/
# Out:
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/EtRfZ2KP_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/Ile3EVQA_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/-1l5631l3fg_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/-1l5631l3fg_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/-1l5631l3fg_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0H2s9UJcNJ0_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0H2s9UJcNJ0_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0H2s9UJcNJ0_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0H2s9UJcNJ0_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0H2s9UJcNJ0_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0lHQ2f0d_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0lHQ2f0d_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0lHQ2f0d_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0lHQ2f0d_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0NWz-01A2yk_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0NWz-01A2yk_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0TFi8D8IBg4_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0_DzLlklZa0_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0_DzLlklZa0_6.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0_DzLlklZa0_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/0_DzLlklZa0_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1060314Σ╕¡σúóσñ⌐µÖƒΘå½ΘÖóµÇÑΦ¿║σ«ñµÜ┤σè¢Σ║ïΣ╗╢∩╝êσì₧Θçæσ│░∩╝ë_17.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1dsLuL5Lvbc_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1dsLuL5Lvbc_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1dsLuL5Lvbc_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1dsLuL5Lvbc_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1DwRGRND_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1DwRGRND_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1tU4kxa51vw_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1XFiS6Lt_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/1XFiS6Lt_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/20130506 05_58 Φù¥Σ║║ Θ╗æµ₧¥_37.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3kpviz7lAMY_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_6.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3CQi0ZCCHvc_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/24E0xYYUz44_7.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3CQi0ZCCHvc_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3CQi0ZCCHvc_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3kpviz7lAMY_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3kpviz7lAMY_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3kpviz7lAMY_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3kpviz7lAMY_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3SS0E4SmTk8_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3SS0E4SmTk8_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/3Vw7MoNBgx4_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4HH7yMU8y9A_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_7.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4HH7yMU8y9A_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_6.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_8.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4RqDG4I4iAk_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yTlGiDoxBo_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yTlGiDoxBo_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yTlGiDoxBo_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yTlGiDoxBo_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yTlGiDoxBo_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yTlGiDoxBo_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/4yzwSsis_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/5QqDgtwEQsI_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6Dej3-k3MRE_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6Dej3-k3MRE_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6Dej3-k3MRE_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6Dej3-k3MRE_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6Dej3-k3MRE_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6mrIIcAQ2fI_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6mrIIcAQ2fI_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7qtRgyFsk3s_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7R1m3V8C30g_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6mrIIcAQ2fI_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/6Dej3-k3MRE_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7qtRgyFsk3s_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7LnoFKSl2rs_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/88ndrvAZpE8_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7R1m3V8C30g_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7Xe6eysGKeU_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/7R1m3V8C30g_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/88ndrvAZpE8_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/8bEO4LGr_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/8pKKdS7rhXo_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/8pKKdS7rhXo_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/8SWZq5we_fk_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/8pKKdS7rhXo_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/9ErNHIovPDI_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/9U8J4abJGDg_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a2qLzOu_n0s_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/8SWZq5we_fk_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a2qLzOu_n0s_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a2qLzOu_n0s_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a2qLzOu_n0s_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a2qLzOu_n0s_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a7gBQaAFEtw_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/a7gBQaAFEtw_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aIg9Yb0O7Hg_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/adg5WJ6y_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aIg9Yb0O7Hg_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aIg9Yb0O7Hg_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aIg9Yb0O7Hg_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aIg9Yb0O7Hg_5.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aIg9Yb0O7Hg_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aKK0B4kpKZA_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/aKK0B4kpKZA_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/AkTZX27QhjE_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/AkTZX27QhjE_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/AkTZX27QhjE_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/AkTZX27QhjE_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/Am9mUxPTvK4_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/ar5ns2zW4lY_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/API3q8TBGu4_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/Am9mUxPTvK4_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/ar5ns2zW4lY_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_107.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_109.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_108.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_110.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_111.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_113.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/b6XfVAZC9Zs_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/b6XfVAZC9Zs_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/b6XfVAZC9Zs_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/b6XfVAZC9Zs_7.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/bzw-HKuuQbg_3.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/bd48s5BpoGY_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/asdasda_112.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/b6XfVAZC9Zs_4.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/b6XfVAZC9Zs_6.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight/BpargJW29Wo_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/train/Fight
0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/qmvilMkD57M_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/qrWTk-2a13o_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/Qqfn1urQ_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/qrWTk-2a13o_2.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/RfFGwwhG_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/qrWTk-2a13o_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/rSumd9HEmrA_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/RGIpCpdlzI8_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/RGIpCpdlzI8_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/RUwo8c4s_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/s-jW4cyavW0_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/s-jW4cyavW0_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/SaIUKN4N_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/skycjZcE_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/sy7BoRGE_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/tPpXT9VI_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/TYsebroPeGY_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/TYsebroPeGY_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/UArjSm2Y_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/Tzn3HwZD_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/UIsigi4O-sI_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/UIsigi4O-sI_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/ULiIpQ6s_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/uNtsEcFR_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/uu3SB2L1_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/V3EI1n_7JwU_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/V89iCOJ1_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/v8cACThQ_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/VbwTMJroTbI_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/VbwTMJroTbI_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/Vd27cYFthms_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/vJDAaUzYOi8_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/vJDAaUzYOi8_1.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/WCHYnPMG_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/wMgaVgMG_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/wNTaSOXj_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/X3mPJLe9_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/XJfaYlr0_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/xW8Esfp9_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/y4njAG00_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/ykI6keNQ_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/yldWawWf_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/Yw7Ip3VS_0.npy [Content-Type=application/octet-stream]...
# Copying file:///content/gdrive/MyDrive/42028/Dataset_Split/new/validation/NonFight/zZHTBiER_0.npy [Content-Type=application/octet-stream]...
# \ [1.6k/1.6k files][ 55.7 GiB/ 55.7 GiB] 100% Done  82.6 MiB/s ETA 00:00:00
# Operation completed over 1.6k objects/55.7 GiB.

# %%
# #example with the videos npy format
# base_dir = '/content/gdrive/MyDrive/42028/rw2000/new/train'
# base_dir2 = '/content/gdrive/MyDrive/42028/rw2000/new/valid'
# # train_dir = os.path.join(base_dir, 'fight')
# # test_dir = os.path.join(base_dir2, 'no-fight')

# %%
#datasets
#dataset = 'RWF2000-opt'
path_train = '/content/gdrive/MyDrive/42028/Dataset_Split/new/train'
path_test = '/content/gdrive/MyDrive/42028/Dataset_Split/new/validation' 


#/content/sample_data/anscombe.json

train_generator = DataGenerator(directory=path_train, 
                                batch_size=batch_size, 
                                data_augmentation=True)

val_generator = DataGenerator(directory=path_test,
                              batch_size=batch_size, 
                              data_augmentation=False)
# Out:
# Found 1207 files belonging to 2 classes.
#      Fight :  0
#   NonFight :  1
# Found 393 files belonging to 2 classes.
#      Fight :  0
#   NonFight :  1

# %%
#start training
with tf.device("/device:GPU:0"):
  hist = model.fit_generator(
      generator=train_generator, 
      validation_data=val_generator,
      callbacks=callbacks_list,
      verbose=1, 
      epochs=num_epochs,
      workers=num_workers ,
      max_queue_size=4,
      steps_per_epoch=len(train_generator),
      validation_steps=len(val_generator))
  
#with multiple GPU
# hist = parallel_model.fit_generator(
#     generator=train_generator, 
#     validation_data=val_generator,
#     callbacks=callbacks_list,
#     verbose=1, 
#     epochs=num_epochs,
#     workers=num_workers ,
#     max_queue_size=4,
#     steps_per_epoch=len(train_generator),
#     validation_steps=len(val_generator))

# %%
# model.save('wr-2000-model.h5')

# %% [markdown]
# ## Look the results

# %%
acc = hist.hist['acc']
val_acc = hist.hist['val_acc']
loss = hist.hist['loss']
val_loss = hist.hist['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'bo', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')

plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training and validation loss')
plt.legend()
plt.ylabel('cost')
plt.xlabel('Epochs')

plt.show()
